# %%
import pandas as pd 
import matplotlib 
import os

# %%
housing_data = pd.read_csv('five_years_data.csv')

# %%
housing_data.head()
# Out:
#    Unnamed: 0 period_begin  period_end           city  state  \
# 0           5   2024-04-01  2024-04-30  Holiday Lakes  Texas
# 1          12   2024-05-01  2024-05-31    Krugerville  Texas
# 2          25   2024-07-01  2024-07-31          Alice  Texas
# 3          47   2021-04-01  2021-04-30          Alice  Texas
# 4          83   2022-11-01  2022-11-30        Watauga  Texas
#
#    property_type_id  median_sale_price  median_list_price  median_ppsf  \
# 0                -1            56000.0           119900.0    58.577406
# 1                -1           712000.0           675000.0   232.662252
# 2                -1           148000.0           165000.0   103.496503
# 3                -1           252000.0           149000.0   106.554703
# 4                -1           284000.0           299900.0   199.408470
#
#    median_list_ppsf  ...  pending_sales  new_listings  inventory  \
# 0        178.422619  ...            1.0           1.0        3.0
# 1        246.702890  ...            6.0          11.0       15.0
# 2        107.415902  ...            9.0          17.0       57.0
# 3         79.824561  ...           16.0          15.0       27.0
# 4        188.335358  ...           22.0          19.0       33.0
#
#    months_of_supply  median_dom  avg_sale_to_list  sold_above_list  \
# 0               3.0       102.0          0.861538         0.000000
# 1               2.5        45.0          0.995242         0.166667
# 2               5.2        64.0          0.926397         0.090909
# 3               4.5       102.0          0.985631         0.333333
# 4               1.8        39.0          0.984357         0.222222
#
#    off_market_in_two_weeks  parent_metro_region parent_metro_region_metro_code
# 0                 0.000000          Houston, TX                          26420
# 1                 0.500000           Dallas, TX                          19124
# 2                 0.333333            Alice, TX                          10860
# 3                 0.312500            Alice, TX                          10860
# 4                 0.272727       Fort Worth, TX                          23104
#
# [5 rows x 21 columns]

# %%
housing_data = housing_data.drop(columns=["Unnamed: 0", 'property_type_id','parent_metro_region', 'parent_metro_region_metro_code'])
housing_data.head()
# Out:
#   period_begin  period_end           city  state  median_sale_price  \
# 0   2024-04-01  2024-04-30  Holiday Lakes  Texas            56000.0
# 1   2024-05-01  2024-05-31    Krugerville  Texas           712000.0
# 2   2024-07-01  2024-07-31          Alice  Texas           148000.0
# 3   2021-04-01  2021-04-30          Alice  Texas           252000.0
# 4   2022-11-01  2022-11-30        Watauga  Texas           284000.0
#
#    median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 0           119900.0    58.577406        178.422619         1.0
# 1           675000.0   232.662252        246.702890         6.0
# 2           165000.0   103.496503        107.415902        11.0
# 3           149000.0   106.554703         79.824561         6.0
# 4           299900.0   199.408470        188.335358        18.0
#
#    pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 0            1.0           1.0        3.0               3.0       102.0
# 1            6.0          11.0       15.0               2.5        45.0
# 2            9.0          17.0       57.0               5.2        64.0
# 3           16.0          15.0       27.0               4.5       102.0
# 4           22.0          19.0       33.0               1.8        39.0
#
#    avg_sale_to_list  sold_above_list  off_market_in_two_weeks
# 0          0.861538         0.000000                 0.000000
# 1          0.995242         0.166667                 0.500000
# 2          0.926397         0.090909                 0.333333
# 3          0.985631         0.333333                 0.312500
# 4          0.984357         0.222222                 0.272727

# %%
# SOURCE: https://simplemaps.com/data/us-cities 
cities_population = pd.read_csv("uscities.csv")

# filter North Carolina, Virginia and Texas 
cities_population = cities_population[cities_population['state_name'].isin(['North Carolina', 'Texas', 'Virginia'])]
# Fetch only city, state_name and population columns 
cities_population = cities_population[['city', 'population', 'state_name']]
cities_population.head()
# Out:
#            city  population      state_name
# 4       Houston     6046392           Texas
# 5        Dallas     5843632           Texas
# 25  San Antonio     2069843           Texas
# 27       Austin     1915031           Texas
# 39    Charlotte     1436613  North Carolina

# %%
# mergind the populaiton datafram into the housind data (addinng us cities cesnus data to the housing data file)
housing_data = pd.merge(housing_data, cities_population, how='left', left_on=['city', 'state'], right_on=['city', 'state_name'])
housing_data = housing_data.drop(columns=['state_name'])

housing_data.head()
# Out:
#   period_begin  period_end           city  state  median_sale_price  \
# 0   2024-04-01  2024-04-30  Holiday Lakes  Texas            56000.0
# 1   2024-05-01  2024-05-31    Krugerville  Texas           712000.0
# 2   2024-07-01  2024-07-31          Alice  Texas           148000.0
# 3   2021-04-01  2021-04-30          Alice  Texas           252000.0
# 4   2022-11-01  2022-11-30        Watauga  Texas           284000.0
#
#    median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 0           119900.0    58.577406        178.422619         1.0
# 1           675000.0   232.662252        246.702890         6.0
# 2           165000.0   103.496503        107.415902        11.0
# 3           149000.0   106.554703         79.824561         6.0
# 4           299900.0   199.408470        188.335358        18.0
#
#    pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 0            1.0           1.0        3.0               3.0       102.0
# 1            6.0          11.0       15.0               2.5        45.0
# 2            9.0          17.0       57.0               5.2        64.0
# 3           16.0          15.0       27.0               4.5       102.0
# 4           22.0          19.0       33.0               1.8        39.0
#
#    avg_sale_to_list  sold_above_list  off_market_in_two_weeks  population
# 0          0.861538         0.000000                 0.000000       853.0
# 1          0.995242         0.166667                 0.500000      1929.0
# 2          0.926397         0.090909                 0.333333     17797.0
# 3          0.985631         0.333333                 0.312500     17797.0
# 4          0.984357         0.222222                 0.272727     23336.0

# %%
# filter Texas data based on cities population size in descending order to know the largest city based on population size 
texas_data = housing_data[housing_data['state']=='Texas']
texas_data = texas_data.sort_values(by='population', ascending=False)
texas_data.head(1)
# Out:
#        period_begin  period_end     city  state  median_sale_price  \
# 181246   2024-07-01  2024-07-31  Houston  Texas           159000.0
#
#         median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 181246           340000.0   150.397082        181.523283       170.0
#
#         pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 181246          185.0         270.0     1074.0               6.3        57.0
#
#         avg_sale_to_list  sold_above_list  off_market_in_two_weeks  population
# 181246          0.954549         0.052941                 0.124324   6046392.0

# %%
# Filter Houston TX data (largest population)
huston_TX = texas_data[texas_data['city']=='Houston']
huston_TX.to_csv("huston_TX_data.csv", index=False)
huston_TX.head(1)
# Out:
#        period_begin  period_end     city  state  median_sale_price  \
# 181246   2024-07-01  2024-07-31  Houston  Texas           159000.0
#
#         median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 181246           340000.0   150.397082        181.523283       170.0
#
#         pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 181246          185.0         270.0     1074.0               6.3        57.0
#
#         avg_sale_to_list  sold_above_list  off_market_in_two_weeks  population
# 181246          0.954549         0.052941                 0.124324   6046392.0

# %%
print(f"number of rows for Huston data is: {len(huston_TX)}")
# Out:
# number of rows for Huston data is: 300

# %%
# Filter the North Carlolina cities population in descending order
NC_data = housing_data[housing_data['state']=='North Carolina']
NC_data = NC_data.sort_values(by='population', ascending=False)
NC_data.head()
# Out:
#        period_begin  period_end       city           state  median_sale_price  \
# 218957   2024-12-01  2024-12-31  Charlotte  North Carolina           389820.0
# 237945   2023-02-01  2023-02-28  Charlotte  North Carolina           560000.0
# 76811    2024-07-01  2024-07-31  Charlotte  North Carolina           405000.0
# 209000   2021-03-01  2021-03-31  Charlotte  North Carolina           304500.0
# 47730    2024-03-01  2024-03-31  Charlotte  North Carolina           335500.0
#
#         median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 218957           395000.0   228.108644        230.832646       174.0
# 237945           399900.0   286.298569        225.218023         3.0
# 76811            400000.0   237.651187        240.014793       204.0
# 209000           330000.0   169.445628        189.646064       272.0
# 47730            420000.0   330.619974        246.101937       136.0
#
#         pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 218957            NaN         147.0      561.0               3.2        52.0
# 237945            NaN           4.0       10.0               3.3        18.0
# 76811             NaN         249.0      609.0               3.0        39.0
# 209000            NaN         293.0      518.0               1.9        35.0
# 47730             NaN         172.0      304.0               2.2        34.0
#
#         avg_sale_to_list  sold_above_list  off_market_in_two_weeks  population
# 218957          0.983007         0.126437                 0.200000   1436613.0
# 237945          1.023028         0.666667                 0.400000   1436613.0
# 76811           0.989842         0.191176                 0.424779   1436613.0
# 209000          1.010810         0.466912                 0.655844   1436613.0
# 47730           0.986313         0.279412                 0.553191   1436613.0

# %%
# Filter out the largest city in North Carolina 
charlotte_data = NC_data[NC_data['city']=='Charlotte']
charlotte_data.to_csv("Charlotte_data.csv", index=False)
charlotte_data.head()
# Out:
#        period_begin  period_end       city           state  median_sale_price  \
# 218957   2024-12-01  2024-12-31  Charlotte  North Carolina           389820.0
# 237945   2023-02-01  2023-02-28  Charlotte  North Carolina           560000.0
# 76811    2024-07-01  2024-07-31  Charlotte  North Carolina           405000.0
# 209000   2021-03-01  2021-03-31  Charlotte  North Carolina           304500.0
# 47730    2024-03-01  2024-03-31  Charlotte  North Carolina           335500.0
#
#         median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 218957           395000.0   228.108644        230.832646       174.0
# 237945           399900.0   286.298569        225.218023         3.0
# 76811            400000.0   237.651187        240.014793       204.0
# 209000           330000.0   169.445628        189.646064       272.0
# 47730            420000.0   330.619974        246.101937       136.0
#
#         pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 218957            NaN         147.0      561.0               3.2        52.0
# 237945            NaN           4.0       10.0               3.3        18.0
# 76811             NaN         249.0      609.0               3.0        39.0
# 209000            NaN         293.0      518.0               1.9        35.0
# 47730             NaN         172.0      304.0               2.2        34.0
#
#         avg_sale_to_list  sold_above_list  off_market_in_two_weeks  population
# 218957          0.983007         0.126437                 0.200000   1436613.0
# 237945          1.023028         0.666667                 0.400000   1436613.0
# 76811           0.989842         0.191176                 0.424779   1436613.0
# 209000          1.010810         0.466912                 0.655844   1436613.0
# 47730           0.986313         0.279412                 0.553191   1436613.0

# %%
print(f'The number of rows in charl')
